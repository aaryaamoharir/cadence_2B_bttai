# %% [markdown]
# # ABSA Results: Aspect Analysis
# ### BTT Cadence 2B
#
# This notebook demonstrates how to analyze individual product aspects in detail.
# Use this as a template for building aspect-specific views in the dashboard.

# %% [markdown]
# # Installations & Imports

# %%
# Numerical computing and data manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

from wordcloud import WordCloud

# Display settings
pd.set_option('display.max_colwidth', 180)
sns.set_style("whitegrid")

# Constants
SEED = 42

# %% [markdown]
# # Data Loading

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/Cadence2B/absa_results/
# Out:
# aspect_sentiments.csv  aspect_summary.csv

# %%
# Load processed ABSA results
aspects_df = pd.read_csv('/content/drive/MyDrive/Cadence2B/dashboard_data/aspect_sentiments.csv')
summary_df = pd.read_csv('/content/drive/MyDrive/Cadence2B/dashboard_data/aspect_summary.csv')

print(f"Loaded {len(aspects_df):,} aspect-sentiment pairs")
print(f"Loaded {len(summary_df):,} unique aspects\n")
# Out:
# Loaded 918,167 aspect-sentiment pairs
# Loaded 93,033 unique aspects

# %% [markdown]
# # Aspect Analysis
#
# Analyze any single aspect deeply.

# %%
def analyze_aspect(aspect_name, aspects_df, show_examples=True, n_examples=3):
    '''
    Perform comprehensive analysis on a single product aspect.

    Parameters:
        aspect_name: Name of the aspect to analyze (e.g., 'battery', 'camera')
        aspects_df: Full aspect-sentiment DataFrame
        show_examples: Whether to display example reviews
        n_examples: Number of example reviews per sentiment

    Returns:
        dict: Analysis results including sentiment breakdown and statistics
    '''

    # Filter data for this aspect
    aspect_data = aspects_df[aspects_df['aspect'] == aspect_name].copy()

    if len(aspect_data) == 0:
        print(f"(X) No data found for aspect: '{aspect_name}'")
        return None

    # Display header
    print("\n" + "=" * 80)
    print(f"ANALYSIS: {aspect_name.upper()}")
    print("=" * 80)

    # Overall statistics
    print(f"\nTotal Mentions: {len(aspect_data):,}")

    if 'review_id' in aspect_data.columns:
        print(f"Unique Reviews: {aspect_data['review_id'].nunique():,}")

    # Sentiment breakdown
    print(f"\nSentiment Distribution:")
    sentiment_counts = aspect_data['sentiment'].value_counts()
    total = len(aspect_data)

    results = {'aspect': aspect_name, 'total': total}

    for sentiment in ['positive', 'neutral', 'negative']:
        count = sentiment_counts.get(sentiment, 0)
        percentage = (count / total) * 100
        print(f"  {sentiment.capitalize():<10}: {count:>6,} ({percentage:>5.1f}%)")
        results[sentiment] = count
        results[f'{sentiment}_pct'] = percentage

    # Sentiment ratio (positive - negative)
    pos_count = sentiment_counts.get('positive', 0)
    neg_count = sentiment_counts.get('negative', 0)
    sentiment_ratio = pos_count / neg_count if neg_count > 0 else float('inf')
    print(f"\nPositive-to-Negative Ratio: {sentiment_ratio:.2f}")
    results['pos_neg_ratio'] = sentiment_ratio

    # Show example reviews
    if show_examples:
        print(f"\n{'─' * 80}")
        print("EXAMPLE REVIEWS")
        print('─' * 80)

        for sentiment in ['positive', 'negative', 'neutral']:
            sentiment_data = aspect_data[aspect_data['sentiment'] == sentiment]

            if len(sentiment_data) > 0:
                print(f"\n{sentiment.upper()} Examples:")
                examples = sentiment_data.sample(min(n_examples, len(sentiment_data)), random_state=SEED)

                for i, (idx, row) in enumerate(examples.iterrows(), 1):
                    print(f"\n  {i}. {row['text'][:200]}...")

    print("\n" + "=" * 80 + "\n")

    return results

# %% [markdown]
# # Visualize Aspect Sentiment

# %%
def plot_aspect_sentiment(aspect_name, aspects_df):
    '''
    Create a stacked bar chart showing sentiment breakdown for an aspect.

    Parameters:
        aspect_name: Name of aspect to visualize
        aspects_df: Full aspect-sentiment DataFrame
    '''

    aspect_data = aspects_df[aspects_df['aspect'] == aspect_name]

    if len(aspect_data) == 0:
        print(f"No data for aspect: {aspect_name}")
        return

    sentiment_counts = aspect_data['sentiment'].value_counts()

    # Color mapping
    colors = {
        'positive': '#2ecc71',
        'neutral': '#95a5a6',
        'negative': '#e74c3c'
    }

    # Create horizontal stacked bar
    fig, ax = plt.subplots(figsize=(12, 3))

    left = 0
    for sentiment in ['positive', 'neutral', 'negative']:
        count = sentiment_counts.get(sentiment, 0)
        percentage = (count / len(aspect_data)) * 100

        ax.barh(0, count, left=left, color=colors[sentiment],
                label=f'{sentiment.capitalize()}: {count:,} ({percentage:.1f}%)')
        left += count

    ax.set_yticks([])
    ax.set_xlabel('Number of Mentions', fontsize=12)
    ax.set_title(f'Sentiment Distribution: {aspect_name}', fontsize=14, fontweight='bold')
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Analyze Top Aspects

# %%
print("=" * 80)
print("TOP 10 ASPECTS - DETAILED ANALYSIS")
print("=" * 80)

# Get top 10 aspects
top_10_aspects = summary_df.head(10)['aspect'].tolist()

# Store results for comparison
analysis_results = []

for aspect in top_10_aspects:
    result = analyze_aspect(aspect, aspects_df, show_examples=False)
    if result:
        analysis_results.append(result)
        plot_aspect_sentiment(aspect, aspects_df)
# Out:
# ================================================================================
# TOP 10 ASPECTS - DETAILED ANALYSIS
# ================================================================================
#
# ================================================================================
# ANALYSIS: SOUND
# ================================================================================
#
# Total Mentions: 9,259
# Unique Reviews: 8,779
#
# Sentiment Distribution:
#   Positive  :  3,918 ( 42.3%)
#   Neutral   :  2,205 ( 23.8%)
#   Negative  :  3,136 ( 33.9%)
#
# Positive-to-Negative Ratio: 1.25
#
# ================================================================================
# ================================================================================
# ANALYSIS: QUALITY
# ================================================================================
#
# Total Mentions: 9,086
# Unique Reviews: 8,803
#
# Sentiment Distribution:
#   Positive  :  4,602 ( 50.6%)
#   Neutral   :  1,454 ( 16.0%)
#   Negative  :  3,030 ( 33.3%)
#
# Positive-to-Negative Ratio: 1.52
#
# ================================================================================
# ================================================================================
# ANALYSIS: HEADPHONES
# ================================================================================
#
# Total Mentions: 6,716
# Unique Reviews: 6,046
#
# Sentiment Distribution:
#   Positive  :  2,536 ( 37.8%)
#   Neutral   :  2,608 ( 38.8%)
#   Negative  :  1,572 ( 23.4%)
#
# Positive-to-Negative Ratio: 1.61
#
# ================================================================================
# ================================================================================
# ANALYSIS: CAMERA
# ================================================================================
#
# Total Mentions: 6,712
# Unique Reviews: 6,100
#
# Sentiment Distribution:
#   Positive  :  1,953 ( 29.1%)
#   Neutral   :  2,774 ( 41.3%)
#   Negative  :  1,985 ( 29.6%)
#
# Positive-to-Negative Ratio: 0.98
#
# ================================================================================
# ================================================================================
# ANALYSIS: VIDEOS
# ================================================================================
#
# Total Mentions: 6,486
# Unique Reviews: 5,950
#
# Sentiment Distribution:
#   Positive  :  1,902 ( 29.3%)
#   Neutral   :  3,027 ( 46.7%)
#   Negative  :  1,557 ( 24.0%)
#
# Positive-to-Negative Ratio: 1.22
#
# ================================================================================
# ================================================================================
# ANALYSIS: THESE HEADPHONES
# ================================================================================
#
# Total Mentions: 6,138
# Unique Reviews: 5,106
#
# Sentiment Distribution:
#   Positive  :  2,947 ( 48.0%)
#   Neutral   :  1,361 ( 22.2%)
#   Negative  :  1,830 ( 29.8%)
#
# Positive-to-Negative Ratio: 1.61
#
# ================================================================================
# ================================================================================
# ANALYSIS: USB
# ================================================================================
#
# Total Mentions: 5,446
# Unique Reviews: 4,619
#
# Sentiment Distribution:
#   Positive  :  1,166 ( 21.4%)
#   Neutral   :  3,310 ( 60.8%)
#   Negative  :    970 ( 17.8%)
#
# Positive-to-Negative Ratio: 1.20
#
# ================================================================================
# ================================================================================
# ANALYSIS: BATTERIES
# ================================================================================
#
# Total Mentions: 5,371
# Unique Reviews: 4,811
#
# Sentiment Distribution:
#   Positive  :  1,360 ( 25.3%)
#   Neutral   :  2,407 ( 44.8%)
#   Negative  :  1,604 ( 29.9%)
#
# Positive-to-Negative Ratio: 0.85
#
# ================================================================================
# ================================================================================
# ANALYSIS: BLUETOOTH
# ================================================================================
#
# Total Mentions: 4,919
# Unique Reviews: 4,408
#
# Sentiment Distribution:
#   Positive  :  1,612 ( 32.8%)
#   Neutral   :  1,912 ( 38.9%)
#   Negative  :  1,395 ( 28.4%)
#
# Positive-to-Negative Ratio: 1.16
#
# ================================================================================
# ================================================================================
# ANALYSIS: REVIEWS
# ================================================================================
#
# Total Mentions: 4,743
# Unique Reviews: 4,566
#
# Sentiment Distribution:
#   Positive  :  1,170 ( 24.7%)
#   Neutral   :  2,091 ( 44.1%)
#   Negative  :  1,482 ( 31.2%)
#
# Positive-to-Negative Ratio: 0.79
#
# ================================================================================

# %% [markdown]
# # Compare sentiment distributions across top aspects

# %%
def plot_aspect_comparison(analysis_results, n=10):
    '''
    Compare sentiment percentages across multiple aspects.

    Parameters:
        analysis_results: List of analysis result dictionaries
        n: Number of aspects to display
    '''

    # Convert to DataFrame
    comparison_df = pd.DataFrame(analysis_results[:n])
    comparison_df = comparison_df.sort_values('total', ascending=True)

    # Create stacked bar chart
    fig, ax = plt.subplots(figsize=(12, 8))

    aspects = comparison_df['aspect']
    y_pos = np.arange(len(aspects))

    # Plot bars
    colors = ['#2ecc71', '#95a5a6', '#e74c3c']
    sentiments = ['positive_pct', 'neutral_pct', 'negative_pct']
    labels = ['Positive', 'Neutral', 'Negative']

    left = np.zeros(len(aspects))

    for sentiment, label, color in zip(sentiments, labels, colors):
        values = comparison_df[sentiment].values
        ax.barh(y_pos, values, left=left, color=color, label=label)

        # Add percentage labels
        for i, (val, l) in enumerate(zip(values, left)):
            if val > 5:  # Only label if > 5%
                ax.text(l + val/2, i, f'{val:.0f}%',
                       ha='center', va='center', fontsize=9, fontweight='bold')

        left += values

    ax.set_yticks(y_pos)
    ax.set_yticklabels(aspects)
    ax.set_xlabel('Percentage', fontsize=12)
    ax.set_title(f'Sentiment Comparison: Top {n} Aspects', fontsize=14, fontweight='bold')
    ax.legend(loc='upper right')
    ax.set_xlim(0, 100)
    plt.tight_layout()
    plt.show()

# %%
plot_aspect_comparison(analysis_results, n=10)

# %% [markdown]
# # Find aspects with high negative sentiment rates

# %%
def identify_problem_aspects(summary_df, min_mentions=100, neg_threshold=40):
    '''
    Identify aspects with concerning negative sentiment rates.

    Parameters:
        summary_df: Aggregated aspect statistics
        min_mentions: Minimum total mentions to consider
        neg_threshold: Minimum negative percentage to flag

    Returns:
        DataFrame: Problem aspects sorted by negative percentage
    '''

    # Filter by minimum mentions
    filtered = summary_df[summary_df['total'] >= min_mentions].copy()

    # Calculate negative percentage
    filtered['negative_pct'] = (filtered['negative'] / filtered['total']) * 100

    # Filter by negative threshold
    problems = filtered[filtered['negative_pct'] >= neg_threshold].copy()
    problems = problems.sort_values('negative_pct', ascending=False)

    return problems[['aspect', 'total', 'negative', 'positive', 'negative_pct']]

# %%
print("\n" + "=" * 80)
print("PROBLEM ASPECTS (>40% Negative Sentiment)")
print("=" * 80)

problem_aspects = identify_problem_aspects(summary_df, min_mentions=100, neg_threshold=40)
print(f"\nFound {len(problem_aspects)} problematic aspects:\n")
print(problem_aspects.to_string(index=False))
# Out:
# ================================================================================
# PROBLEM ASPECTS (>40% Negative Sentiment)
# ================================================================================
#
# Found 177 problematic aspects:
#
#                 aspect  total  negative  positive  negative_pct
#           Poor quality    595       595         0    100.000000
#          Complete junk    100       100         0    100.000000
#       terrible quality    125       125         0    100.000000
#       Terrible quality    118       118         0    100.000000
#            Bad quality    109       109         0    100.000000
#      Very poor quality    181       181         0    100.000000
#       Not good quality    123       123         0    100.000000
#            Poor design    193       193         0    100.000000
#      very poor quality    300       295         5     98.333333
#     Poor sound quality    187       182         0     97.326203
#           poor quality    960       929        10     96.770833
#       very low quality    143       138         0     96.503497
#            poor design    172       163         0     94.767442
#   poor quality control    141       131        10     92.907801
#            Low quality    109       100         9     91.743119
#            bad quality    109        96        13     88.073394
#            low quality    445       386        31     86.741573
#     poor sound quality    159       136        19     85.534591
#            its battery    101        83         9     82.178218
#               any apps    103        80        13     77.669903
#           just a piece    101        77        10     76.237624
#             keystrokes    110        81        14     73.636364
#               RT-AC68U    160       117        14     73.125000
#            any devices    152       110         8     72.368421
#            low battery    242       163         2     67.355372
#        another headset    104        70        12     67.307692
#        quality control    514       333        44     64.785992
#          their devices    273       172        19     63.003663
#   wireless connections    124        77        12     62.096774
#          new batteries    379       231        24     60.949868
#               one part    115        70         5     60.869565
#             no battery    125        76         4     60.800000
#          their reviews    257       156        24     60.700389
#            HP products    106        64        29     60.377358
# Bluetooth connectivity    244       147        73     60.245902
#              many apps    114        68        35     59.649123
#          documentation    471       279        43     59.235669
#                Drivers    122        72        18     59.016393
#  internet connectivity    112        66        12     58.928571
#           some devices    160        94        10     58.750000
#          missing parts    144        84        15     58.333333
#                    Mic    309       179        52     57.928803
#           one earphone    100        57         7     57.000000
#   bluetooth connection    153        87        38     56.862745
#           these camera    132        75        33     56.818182
#               each ear    133        75        14     56.390977
#             our camera    126        71        23     56.349206
#          one headphone    118        66         5     55.932203
#                    App    866       473       172     54.618938
#          These cameras    923       502       265     54.387866
#             distortion    599       325       107     54.257095
#               Software    415       225        95     54.216867
#         their software    401       217        45     54.114713
#         other chargers    134        72        20     53.731343
#           hard plastic    272       146        33     53.676471
#                Surface    111        59        26     53.153153
#           connectivity   1042       553       244     53.071017
#              sound bar    121        64        18     52.892562
#          power adapter    104        55        20     52.884615
#                android    145        76        13     52.413793
#         very light use    205       107        25     52.195122
#        security camera    146        76        20     52.054795
#        better products    198       103        38     52.020202
#        These batteries    302       157        85     51.986755
#                Charger    485       252       113     51.958763
#               3 cables    137        71        25     51.824818
#              some apps    141        73        12     51.773050
#               Magnavox    172        89        21     51.744186
#                   disc    128        66        13     51.562500
#             Microphone    330       170       111     51.515152
#         all the screws    132        68        16     51.515152
#                   Part    298       152        45     51.006711
#                  flaws    220       112        32     50.909091
#             any device    661       335       111     50.680787
#              CD player    407       206        60     50.614251
#              accessory    105        53        35     50.476190
#                   WIFI    382       192        83     50.261780
#                Battery   2240      1121       518     50.044643
#            new cameras    112        56         1     50.000000
#            motherboard    224       111        32     49.553571
#                   spec    254       124        36     48.818898
#                  Wires    121        59        20     48.760331
#            one battery    233       113        43     48.497854
#       factory settings    219       106         8     48.401826
#                sd card    153        74        22     48.366013
#          Audio quality    189        91        70     48.148148
#           speakers.<br    106        51        19     48.113208
#                100mbps    119        57        28     47.899160
#               charging    186        89        37     47.849462
#                  Razer    253       121        62     47.826087
#            no software    159        76        41     47.798742
#          cheap quality    134        64        37     47.761194
#      their description    107        51        25     47.663551
#                 Videos    201        95        26     47.263682
#         These chargers    174        82        66     47.126437
#           power source    104        49        17     47.115385
#                screens    319       150        57     47.021944
#                Speaker    413       194       101     46.973366
#         their products   1673       785       560     46.921698
#               firmware    767       359       131     46.805737
#   all the good reviews    156        73        66     46.794872
#          these devices    483       226        64     46.790890
#                   Wifi    651       304        95     46.697389
#    different computers    105        49         8     46.666667
#                 rating    298       139        42     46.644295
#           other models    307       143        50     46.579805
#           Touch screen    131        61        39     46.564885
#               consoles    101        47        21     46.534653
#            no speakers    142        66        18     46.478873
#                  apple    516       237       115     45.930233
#            quality.<br    144        66        56     45.833333
#                  parts   1225       561       143     45.795918
#                drivers   1187       541       169     45.577085
#                linksys    123        56        21     45.528455
#          build quality    313       142       124     45.367412
#                Adapter    146        66        26     45.205479
#          these cameras   3806      1717       855     45.112980
#          all the wires    200        90        26     45.000000
#                  Cisco    287       129        35     44.947735
#          some speakers    116        52        23     44.827586
#          manufacturers    114        51        24     44.736842
#         another laptop    130        58        41     44.615385
#           his computer    173        77        21     44.508671
#        several devices    227       101        29     44.493392
#          their cameras    117        52        25     44.444444
#                   WiFi   1646       730       324     44.349939
#            fast charge    149        66        39     44.295302
#          home security    289       128        61     44.290657
#             no drivers    122        54        39     44.262295
#             some parts    165        73        25     44.242424
#      many applications    104        46        19     44.230769
#               CloudCam    109        48        33     44.036697
#                   Apps    187        82        36     43.850267
#          their quality    211        92       105     43.601896
#                sensors    280       122        45     43.571429
#             Resolution    163        71        53     43.558282
#                   disk    163        71        11     43.558282
#                  shape    754       328       226     43.501326
#            these wires    141        61        22     43.262411
#               standard    148        64        15     43.243243
#      regular batteries    111        48        14     43.243243
#                Buttons    449       194        92     43.207127
#                  wi-fi    225        97        55     43.111111
#                 charge   2947      1264       563     42.891076
#               Motorola    201        86        53     42.786070
#                 Lenovo    875       374        92     42.742857
#                   apps   1807       770       388     42.612064
#                   wifi   3432      1461       624     42.569930
#         Sounds quality    141        60        79     42.553191
#         these chargers    254       108        81     42.519685
#          another mouse    106        45        14     42.452830
#                factory    427       181        68     42.388759
#                signals    515       218        69     42.330097
#               software   2785      1177       574     42.262118
#                  knobs    154        65        32     42.207792
#         device manager    109        46         0     42.201835
#             its weight    128        54        20     42.187500
#            our iPhones    126        53        19     42.063492
#                Linksys    768       321       114     41.796875
#                  Cable   1469       613       384     41.729067
#           their device    113        47        35     41.592920
#      wireless charging    101        42        40     41.584158
#        Samsung support    109        45         1     41.284404
#                  Parts    107        44        33     41.121495
#            One battery    112        46        36     41.071429
#          fast charging    542       222       176     40.959410
#                 Screen   1087       445       247     40.938362
#               Monitors    125        51         6     40.800000
#                   bios    152        62         9     40.789474
#                  ipads    103        42        31     40.776699
#                battery   3983      1608       994     40.371579
#                  Phone    330       133       103     40.303030
#       security cameras    311       125        39     40.192926
#         />The keyboard    142        57        57     40.140845
#             capability    182        73        80     40.109890
#             Headphones    577       231       242     40.034662
#              usb cable    100        40        14     40.000000

# %% [markdown]
# # Find aspects with high positive sentiment rates

# %%
def identify_strength_aspects(summary_df, min_mentions=100, pos_threshold=60):
    '''
    Identify aspects with strong positive sentiment rates.

    Parameters:
        summary_df: Aggregated aspect statistics
        min_mentions: Minimum total mentions to consider
        pos_threshold: Minimum positive percentage to flag

    Returns:
        DataFrame: Strength aspects sorted by positive percentage
    '''

    filtered = summary_df[summary_df['total'] >= min_mentions].copy()
    filtered['positive_pct'] = (filtered['positive'] / filtered['total']) * 100

    strengths = filtered[filtered['positive_pct'] >= pos_threshold].copy()
    strengths = strengths.sort_values('positive_pct', ascending=False)

    return strengths[['aspect', 'total', 'positive', 'negative', 'positive_pct']]

# %%
print("\n" + "=" * 80)
print("STRENGTH ASPECTS (>60% Positive Sentiment)")
print("=" * 80)

strength_aspects = identify_strength_aspects(summary_df, min_mentions=100, pos_threshold=60)
print(f"\nFound {len(strength_aspects)} strength aspects:\n")
print(strength_aspects.head(20).to_string(index=False))
# Out:
# ================================================================================
# STRENGTH ASPECTS (>60% Positive Sentiment)
# ================================================================================
#
# Found 107 strength aspects:
#
#                aspect  total  positive  negative  positive_pct
#        Great features    110       110         0    100.000000
#       Quality product    153       153         0    100.000000
#          Great device    152       152         0    100.000000
#          Perfect size    139       139         0    100.000000
#     Very good quality    322       320         1     99.378882
#          Great screen    147       146         1     99.319728
#          perfect size    120       119         0     99.166667
#   pretty good quality    103       102         0     99.029126
#         Great quality   1090      1064        25     97.614679
#     excellent quality    258       250         1     96.899225
#         Great monitor    311       301        10     96.784566
#     Excellent quality    346       333         7     96.242775
#    Great battery life    186       179         7     96.236559
#          High quality    212       203         8     95.754717
#             Nice size    135       128         7     94.814815
#            Great size    168       159         5     94.642857
#     Good battery life    150       141         0     94.000000
#          Great laptop    119       111         8     93.277311
#     good battery life    299       277        22     92.642140
# Great picture quality    255       236        14     92.549020

# %%
def search_aspects(query, summary_df, aspects_df):
    '''
    Search for aspects matching a query string.

    Parameters:
        query: Search term (e.g., 'batter', 'sound')
        summary_df: Aspect summary statistics
        aspects_df: Full aspect-sentiment data

    Returns:
        DataFrame: Matching aspects with statistics
    '''

    # Find matching aspects
    matches = summary_df[summary_df['aspect'].str.contains(query, case=False, na=False)]

    if len(matches) == 0:
        print(f"No aspects found matching '{query}'")
        return None

    print(f"Found {len(matches)} aspects matching '{query}':\n")
    print(matches[['aspect', 'total', 'positive', 'negative', 'neutral']].to_string(index=False))

    return matches

# %%
# Example searches
print("\n" + "=" * 80)
print("EXAMPLE: Search for battery-related aspects")
print("=" * 80)
search_aspects('batter', summary_df, aspects_df)

print("\n" + "=" * 80)
print("EXAMPLE: Search for sound-related aspects")
print("=" * 80)
search_aspects('sound', summary_df, aspects_df)

print("Go to 03_Disagreement_Analysis.ipynb for disagreement case analysis")
# Out:
# ================================================================================
# EXAMPLE: Search for battery-related aspects
# ================================================================================
# Found 3115 aspects matching 'batter':
#
#                                                                                                                             aspect  total  positive  negative  neutral
#                                                                                                                          batteries   5371      1360      1604     2407
#                                                                                                                            battery   3983       994      1608     1381
#                                                                                                                       battery life   3339      1329      1074      936
#                                                                                                                       Battery life   2755      1454       773      528
#                                                                                                                            Battery   2240       518      1121      601
#                                                                                                                    these batteries    886       159       343      384
#                                                                                                                          Batteries    816       170       216      430
#                                                                                                                      battery power    395        96        95      204
#                                                                                                                      new batteries    379        24       231      124
#                                                                                                                    These batteries    302        85       157       60
#                                                                                                                  good battery life    299       277        22        0
#                                                                                                                  long battery life    295       210        43       42
#                                                                                                                    extra batteries    292        91        41      160
#                                                                                                                 great battery life    262       228        26        8
#                                                                                                                        low battery    242         2       163       77
#                                                                                                                        one battery    233        43       113       77
#                                                                                                                       AA batteries    229        61        42      126
#                                                                                                                     />Battery life    214       105        57       52
#                                                                                                                 Great battery life    186       179         7        0
#                                                                                                                       no batteries    158        33        61       64
#                                                                                                                    spare batteries    151        45        37       69
#                                                                                                                  Good battery life    150       141         0        9
#                                                                                                                    fresh batteries    146        16        42       88
#                                                                                                                         no battery    125         4        76       45
#                                                                                                                        One battery    112        36        46       30
#                                                                                                                  regular batteries    111        14        48       49
#                                                                                                                    another battery    111        23        35       53
#                                                                                                                        3 batteries    110        19        14       77
#                                                                                                                  all the batteries    109        27        41       41
#                                                                                                                        its battery    101         9        83        9
#                                                                                                                   battery life.<br     98        54         5       39
#                                                                                                                better battery life     94        64         1       29
#                                                                                                                  Long battery life     91        78         1       12
#                                                                                                                brand new batteries     89        15        56       18
#                                                                                                                longer battery life     83        27        24       32
#                                                                                                                          />Battery     81        39        11       31
#                                                                                                                        new battery     81         5        34       42
#                                                                                                                        8 batteries     77        36        15       26
#                                                                                                             excellent battery life     73        67         0        6
#                                                                                                                decent battery life     73        53         0       20
#                                                                                                                      all batteries     72        10        30       32
#                                                                                                                   how much battery     70        43        16       11
#                                                                                                                      />The battery     69        28        28       13
#                                                                                                                       Battery Life     67        13        45        9
#                                                                                                                        any battery     66         8        33       25
#                                                                                                                    other batteries     65        14        19       32
#                                                                                                                   its battery life     64        14        39       11
#                                                                                                                     more batteries     64        10         4       50
#                                                                                                                     some batteries     61        12        13       36
#                                                                                                                       battery pack     60        25         9       26
#                                                                                                                 short battery life     56         6        49        1
#                                                                                                                 Short battery life     56         7        26       23
#                                                                                                                     battery charge     56        24         9       23
#                                                                                                              replaceable batteries     56        12        24       20
#                                                                                                                       battery mode     55         1         9       45
#                                                                                                                      battery drain     55         3        42       10
#                                                                                                                 />The battery life     55        21        29        5
#                                                                                                                       battery time     53        13        13       27
#                                                                                                                    battery charger     53         7         4       42
#                                                                                                                  more battery life     53         4        11       38
#                                                                                                                      battery packs     52        28         5       19
#                                                                                                                    their batteries     51         4        28       19
#                                                                                                                     battery issues     50         1        48        1
#                                                                                                                  lithium batteries     50        15        20       15
#                                                                                                                  Poor battery life     50         0        50        0
#                                                                                                                      extra battery     50        31         0       19
#                                                                                                                    those batteries     50         2        20       28
#                                                                                                                        4 batteries     47         5        10       32
#                                                                                                               rechargeable battery     47        19         0       28
#                                                                                                                     one AA battery     45        21         0       24
#                                                                                                                      battery level     44         7        17       20
#                                                                                                               amazing battery life     43        43         0        0
#                                                                                                                      New batteries     41        16        25        0
#                                                                                                                Decent battery life     41        25        16        0
#                                                                                                                   battery chargers     41         3         7       31
#                                                                                                                    three batteries     41         3         3       35
#                                                                                                                   bad battery life     40         0        31        9
#                                                                                                                battery replacement     39         2        27       10
#                                                                                                                      OEM batteries     38         4         6       28
#                                                                                                                      spare battery     38        18         1       19
#                                                                                                                      batteries.<br     37         4         8       25
#                                                                                                              how much battery life     37         8        15       14
#                                                                                                                   all my batteries     36        17         7       12
#                                                                                                                   Original battery     36         0         6       30
#                                                                                                                   original battery     35        12         1       22
#                                                                                                                 standard batteries     35         2         0       33
#                                                                                                              Terrible battery life     34         0        34        0
#                                                                                                               additional batteries     34         6         9       19
#                                                                                                                      Great battery     34        34         0        0
#                                                                                                                       each battery     34         8         0       26
#                                                                                                                   battery problems     34         8        20        6
#                                                                                                                       good battery     32        29         3        0
#                                                                                                                  several batteries     32        16         0       16
#                                                                                                                        battery&#34     32         0        27        5
#                                                                                                                3rd party batteries     31         0        28        3
#                                                                                                                replacement battery     31         9         6       16
#                                                                                                                    Fresh batteries     31         7        24        0
#                                                                                                                       more battery     30         2         5       23
#                                                                                                                     Good batteries     30        30         0        0
#                                                                                                                battery performance     30         1        28        1
#                                                                                                                        old battery     29         2        22        5
#                                                                                                                     battery backup     29         0         4       25
#                                                                                                                       No batteries     29        16         4        9
#                                                                                                                       Good battery     29        29         0        0
#                                                                                                                      First battery     29         0        14       15
#                                                                                                                          1 battery     29         4         6       19
#                                                                                                                      whose battery     29        13         3       13
#                                                                                                                       full battery     28        11         3       14
#                                                                                                            very short battery life     27         2        25        0
#                                                                                                                   just the battery     27         0        15       12
#                                                                                                                     camera battery     27        10        14        3
#                                                                                                                  charged batteries     27         6         0       21
#                                                                                                                different batteries     27         4        13       10
#                                                                                                                   normal batteries     27         1         3       23
#                                                                                                                      phone battery     26        11         0       15
#                                                                                                                  poor battery life     26         0        26        0
#                                                                                                                    no battery life     26         9        12        5
#                                                                                                                 more battery power     26         0        13       13
#                                                                                                                   only the battery     26        11        13        2
#                                                                                                                  battery longevity     26         1         4       21
#                                                                                                                   battery strength     26         2         8       16
#                                                                                                            different battery lives     26         0        26        0
#                                                                                                                      their battery     25         0        23        2
#                                                                                                                     what batteries     25         0         0       25
#                                                                                                                battery compartment     25         0        24        1
#                                                                                                                      great battery     24        20         4        0
#                                                                                                                 multiple batteries     24         7        16        1
#                                                                                                                     Battery charge     24         1         0       23
#                                                                                                                        battery.<br     24        18         3        3
#                                                                                                                            BATTERY     24         1        21        2
#                                                                                                             Very good battery life     24        24         0        0
#                                                                                                                       1 AA battery     24         4         9       11
#                                                                                                                Replaceable battery     24        23         0        1
#                                                                                                                    battery savings     24         0         0       24
#                                                                                                                    brand batteries     24        23         1        0
#                                                                                                                     4 AA batteries     23        15         2        6
#                                                                                                                     four batteries     23         2         9       12
#                                                                                                                battery consumption     23         1        13        9
#                                                                                                           battery operated cameras     23         1        14        8
#                                                                                                                     battery saving     23         0        23        0
#                                                                                                                     3 AA batteries     23         0        16        7
#                                                                                                               some spare batteries     23         0         9       14
#                                                                                                              extended battery life     23        18         4        1
#                                                                                                                expensive batteries     22        17         0        5
#                                                                                                              third party batteries     22         0        11       11
#                                                                                                                   Replaced battery     22         1        13        8
#                                                                                                                        BATTERY LOW     22         0        15        7
#                                                                                                                     good batteries     22         4         3       15
#                                                                                                                Battery compartment     21         0        21        0
#                                                                                                                 both the batteries     21        21         0        0
#                                                                                                                rechargable battery     21        12         0        9
#                                                                                                                       16 batteries     21         0         7       14
#                                                                                                                      which battery     20         0         0       20
#                                                                                                                    all the battery     20         1         2       17
#                                                                                                                       Battery case     20         1        19        0
#                                                                                                                    charged battery     20         3         0       17
#                                                                                                       Great sound and battery life     20        14         6        0
#                                                                                                                    battery changes     20        10         0       10
#                                                                                                                        New battery     20        10        10        0
#                                                                                                                   internal battery     20         2         0       18
#                                                                                                                 super battery life     20         6        14        0
#                                                                                                            battery saving purposes     19         3        16        0
#                                                                                                                      battery saver     19         1         8       10
#                                                                                                                 internal batteries     19         1         4       14
#                                                                                                        other third party batteries     19         0         0       19
#                                                                                                                 just the batteries     19         1         0       18
#                                                                                                                enough battery life     19         7         0       12
#                                                                                                              standard AA batteries     19         1        12        6
#                                                                                                    professionals.<br />Battery hog     19        19         0        0
#                                                                                                                     backup battery     19         4         0       15
#                                                                                                     not a bad battery storage case     18         0        18        0
#                                                                                                                     batt batteries     18        18         0        0
#                                                                                                                     second battery     18        15         2        1
#                                                                                                                   any battery life     18         0        18        0
#                                                                                                                      any batteries     18         8         7        3
#                                                                                                                      our batteries     18         4         9        5
#                                                                                                                   just one battery     18        16         1        1
#                                                                                                                      Apple battery     18        17         0        1
#                                                                                                      every imaginable battery type     18         0         0       18
#                                                                                                                   Low battery life     18         7         5        6
#                                                                                                                     many batteries     18         0        14        4
#                                                                                                                removable batteries     18         0         0       18
#                                                                                                                        C batteries     18         1        13        4
#                                                           compact, portable, self-powered or rechargeable battery-powered speakers     18        18         0        0
#                                                                                                             Excellent battery life     18        18         0        0
#                                                                                                               fit and battery life     18        18         0        0
#                                                                                                                    battery storage     18        12         0        6
#                                                                                                                 their battery life     18         2        13        3
#                                                                                                              promised battery life     18         0        18        0
#                                                                                                               prolong battery life     18         0         0       18
#                                                                                                             Battery 'effectiveness     17         0         0       17
#                                                                                                                   (2) Battery life     17         0         0       17
#                                                                                                              terrible battery life     17         0        17        0
#                                                                                                                   battery charging     17         3        13        1
#                                                                                                                     battery damage     17         0        17        0
#                                                                                                           battery cycle life count     17         0         0       17
#                                                                                                           battery/memory card door     17         0        17        0
#                                                                                                                    all 4 batteries     17         1         0       16
#                                                                                                                  its cover/battery     17         0         0       17
#                                                                                                      br />- Optimize Battery Usage     17         0         0       17
#                                                                                                           EXPENSIVE battery issues     17         0         0       17
#                                                                                                        SD card/battery compartment     17         0        17        0
#                                                                                                        some rechargeable batteries     17         0         0       17
#                                                                                                                   Its battery life     17         3        13        1
#                                                                                                                       "low battery     17         0        17        0
#                                                                                                                   camera batteries     17         2        10        5
#                                                                                                                     decent battery     17        17         0        0
#                                                                                                                       Battery time     16         6        10        0
#                                                                                            discharged.<br /><br />The battery life     16        16         0        0
#                                                                                               three months.<br /><br />The battery     16         0        16        0
#                                                                                                                        6 batteries     16         0         3       13
#                                                                                                                   8hr battery life     16        16         0        0
#                                                                                                            Also solid battery life     16        16         0        0
#                                                                                                                    EXTRA BATTERIES     16        10         0        6
#                                                                                                             great and battery life     16         6        10        0
#                                                                                                                      stock battery     16         0         5       11
#                                                                                                                replaceable battery     16         6         0       10
#                                                                                                                         AA battery     16         1        13        2
#                                                                                                                  some battery life     16         0         6       10
#                                                                                                            around 29% battery life     16         0        16        0
#                                                                                                                      its batteries     16         5         8        3
#                                                                                                      multiple battery replacements     16         0        16        0
#                                                                                                                    older batteries     16         1         3       12
#                                                                                                                  4 battery housing     16         0        16        0
#                                                                                                                   Terrible battery     16         0        16        0
#                                                                                                                     battery status     16         0        10        6
#                                                                                                                     battery length     16         0        16        0
#                                                                                                                  not the batteries     16         0         0       16
#                                                                                                                    Battery charges     15         0        14        1
#                                                                                                                 Original batteries     15        14         1        0
#                                                                                                            rapid battery depletion     15         0        15        0
#                                                                                                                All these batteries     15         0        15        0
#                                                                                                                          BATTERIES     15         0         9        6
#                                                                                                                  generic batteries     15         0         1       14
#                                                                                                             similar battery issues     15         0        15        0
#                                                                                                       great , terrfic battery life     15        15         0        0
#                                                                                                   -tripod, spare battery & SD card     15         0        15        0
#                                                                                                          both the internal battery     15         0         0       15
#                                                                                                         much less a laptop battery     15         0        15        0
#                                                                                                  Decent battery life.<br /><br />6     15         0        15        0
#                                                                                                              battery functionality     15         0        15        0
#                                                                                                                  various batteries     15        13         2        0
#                                                                                                                        battery use     15         2         0       13
#                                                                                                                    />All Batteries     15         0        15        0
#                                                                                                              % battery percentages     15         0        15        0
#                                                                                                                     Battery Backup     14         3         0       11
#                                                                                                                  many AA batteries     14         0        14        0
#                                                                                        their own "Chinese-made Panasonic batteries     14         0        14        0
#                                                                                                                          3 battery     14         0         0       14
#                                                                                                                 battery saver mode     14        12         0        2
#                                                                                                                    "White" battery     14         0         0       14
#                                                                                                        battery and battery charger     14         0         0       14
#                                                                                                                   1battery charges     14         0        14        0
#                                                                                                                    battery "safety     14         0        14        0
#                                                                                                            40 percent battery life     14         0        14        0
#                                                                                                       great sound and battery life     14        14         0        0
#                                                                                                                   backup batteries     14         9         5        0
#                                                                                                          Definitely a used battery     14         0        14        0
#                                                                                                             sound and battery life     14         6         0        8
#                                                                                                                  , 450 mAh battery     14         0         0       14
#                                                                                                               awesome battery life     14        14         0        0
#                                                                                                               Amazing battery life     14        14         0        0
#                                                                                                                      small battery     14         0         9        5
#                                                                                                                  Regular batteries     14         2         1       11
#                                                                                                              extended battery time     14         0         0       14
#                                                                                                            really bad battery life     14         0        14        0
#                                                                                                                        OEM battery     14         2         0       12
#                                                                                                                        50% battery     14         4         8        2
#                                                                                                              bluetooth 40% battery     14         0        14        0
#                                                                                                                    orginal battery     14         0         0       14
#                                                                                                                       100% battery     14         3         2        9
#                                                                                                                 Super battery life     14        14         0        0
#                                                                                                                       BATTERY LIFE     14         9         5        0
#                                                                                                  only Official Panasonic batteries     14         0        14        0
#                                                                                                                  All the batteries     14         6         2        6
#                                                                                                                   Bad battery life     14         0        14        0
#                                                                                                               "Infolythium battery     13         0        13        0
#                                                                                                   just fine, battery health report     13         0        13        0
#                                                                                                               as much battery life     13         0        13        0
#                                                                                                                     Either battery     13         0         8        5
#                                                                                                fairly inexpensive, 3) battery life     13        13         0        0
#                                                                                                           either a battery warning     13         0        13        0
#                                                                                                               external battery.<br     13        13         0        0
#                                                                                                              other brand batteries     13         0         9        4
# ...
#                                                                                                              all the sound quality benefits      1         1         0        0
#                                                                                                                       all the sound options      1         0         0        1
#                                                                                                                         all the sound modes      1         0         0        1
#                                                                                                               />The headphone sound quality      1         0         1        0
#                                                                                                       use and connection call quality sound      1         1         0        0
#                                                                                                           use.<br /><br />The sound quality      1         1         0        0
#                                                                                              use.<br />Incredible sound and picture quality      1         1         0        0
#                                                                                                               used,15/10 best sound quality      1         1         0        0
#                                                                                                                           />The Soundfly SD      1         1         0        0
#                                                                                                    />The Revolve+ SoundLink portable device      1         0         0        1
#                                                                                                                             />Sound:<br />I      1         1         0        0
#                                                                                                                    />Sound:<br /><br />Much      1         1         0        0
#                                                                                                                    various sound signatures      1         0         0        1
#                                                                                                                         various sound modes      1         0         0        1
#                                                                                                                             />Quality sound      1         1         0        0
#                                                                                                />Original review:<br />Okay headphone sound      1         1         0        0
#                                                                                                                 vastly better sound quality      1         1         0        0
#                                                                                                               very accurate and crisp sound      1         1         0        0
#                                                                                                                       very acceptable sound      1         1         0        0
#                                                                                                                          all my video sound      1         1         0        0
#                                                                                                      very affordable, amazing sound quality      1         1         0        0
#                                                                                                                 very clear and robust sound      1         1         0        0
#                                                                                                                         very clean sounding      1         1         0        0
#                                                                                                  very clear sound, amazing and fancy design      1         1         0        0
#                                                                                                                    very clear quality sound      1         1         0        0
#                                                                                                               very comfortable, clear sound      1         1         0        0
#                                                                                                   very clear, realistic sounding recordings      1         1         0        0
#                                                                                                                very compatible, clear sound      1         1         0        0
#                                                                                                                       very comparable sound      1         1         0        0
#                                                                                                                     very crisp, clear sound      1         1         0        0
#                                                                                                                   very decent sound quality      1         1         0        0
#                                                                                                                           very decent sound      1         1         0        0
#                                                                                                                  />Good fit and great sound      1         1         0        0
#                                                                                                       />Crystal clear sound.<br />Efficient      1         1         0        0
#                                                                                                                   very good sound qualities      1         1         0        0
#                                                                                                                         very good sound bar      1         1         0        0
#                                                                                                                     />Amazing sound quality      1         1         0        0
#                                                                                                                     very high-quality sound      1         1         0        0
#                                                                                                                 very loud, very clean sound      1         1         0        0
#                                                                                           all other wear and tear.<br />Great sound quality      1         1         0        0
#                                                                                                                     very nive sound quality      1         1         0        0
#                                                                                                                     very nice sound quality      1         1         0        0
#                                                                                                                       /><br />SOUND.<br />I      1         1         0        0
#                                                                                                                 very pleasing sound quality      1         1         0        0
#                                                                                                                          /><br />Good sound      1         1         0        0
#                                                                                                                   very portable, good sound      1         1         0        0
#                                                                                                                   />-Increase sound quality      1         1         0        0
#                                                                                                                    very sturdy, great sound      1         1         0        0
#                                                                                                                                      .Sound      1         1         0        0
#                                                                                                                              -Sound quality      1         1         0        0
#                                                                                                                        - good sound quality      1         1         0        0
#                                                                                                                             video/sound.<br      1         0         1        0
#                                                                                                                         video/sound editing      1         1         0        0
#                                                                                                                                 vocal sound      1         1         0        0
#                                                                                                                       , clear sounded music      1         1         0        0
#                                                                                                                                 voice/sound      1         1         0        0
#                                                                                                                      , crisp ambient sounds      1         1         0        0
#                                                                                                                              w/ great sound      1         1         0        0
#                                                                                                                           all sound formats      1         0         0        1
#                                                                                                                           all sound effects      1         0         1        0
#                                                                                                                         well balanced sound      1         1         0        0
#                                                                                                                 well and good sound quality      1         1         0        0
#                                                                                                              well built and fantastic sound      1         1         0        0
#                                                                                                                    well great sound quality      1         1         0        0
#                                                                                                                          what a great sound      1         1         0        0
#                                                                                                                          all the fake sound      1         0         1        0
#                                                                                                                    what great sound quality      1         1         0        0
#                                                                                                                             what good sound      1         1         0        0
#                                                                                                                what so ever and great sound      1         1         0        0
#                                                                                                            whatever other apps output sound      1         0         0        1
#                                                                                                               what type sound configuration      1         1         0        0
#                                                                                                    (foam) sound quality and noise reduction      1         1         0        0
#                                                                                                                    (Soundfly/satechi) brand      1         1         0        0
#                                                                                                                       wicked surround sound      1         1         0        0
#                                                                                                                         whose sound quality      1         0         0        1
#                                                                                                                      wide, clear soundstage      1         1         0        0
#                                                                                                                         (Great 'live' sound      1         1         0        0
#                                                                                                     (2) the sound quality and dynamic range      1         1         0        0
#                                                                                                            $200 Bose surround sound quality      1         0         1        0
#                                                                                                                      wit hthe sound quality      1         1         0        0
#                                                                                                                   wonderfull, perfect sound      1         1         0        0
#                                                                                          wonderful, crisp and controlled sound reproduction      1         1         0        0
#                                                                                                                    wonderful sounding music      1         1         0        0
#                                                                                                               wonderful rich powerful sound      1         1         0        0
#                                                                                                                       wow the sound quality      1         1         0        0
#                                                                                                                       you home sound system      1         1         0        0
#                                                                                                                 zoom and good sound quality      1         1         0        0
#                                                                                                              "MP3 quality" compressed sound      1         1         0        0
#                                                                                                                       ✅ Great sound quality      1         1         0        0
#                                                                                                                          •The sound quality      1         1         0        0
# Go to 03_Disagreement_Analysis.ipynb for disagreement case analysis
